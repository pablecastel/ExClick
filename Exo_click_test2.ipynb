# %% [markdown]
# # ExoClick Technical Test - 2
#
# ## 1. Objectives
#
# - Understand what ads are more profitable and has the best performance
#     - by country
#     - by day of the week
#     - by hour of the day

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r'C:\Users\pablo\Desktop\ExoClick\data_test2_clean.csv')

# %%
# Box plot to observe the outliers in the eCPM

df['eCPM'].plot(kind='box')
# Out:
# <Axes: >

# %%
df['eCPM'].quantile(q=0.99)
# Out:
# 25.0

# %%
df.sort_values(by='eCPM', ascending=False).head(40)
# Out:
#                   datetime  client country  ad_type  total_impressions  \
# 34941  2021-06-15 15:00:00       4     NCL       15                 20
# 16825  2021-06-29 07:00:00      51     NCL       17               1363
# 25563  2021-06-29 06:00:00      51     NCL       15                650
# 58772  2021-06-29 07:00:00      51     NCL        2               1410
# 95316  2021-06-29 06:00:00      51     NCL       10                570
# 78005  2021-06-29 11:00:00      70     EST       10                201
# 74252  2021-06-29 11:00:00      70     ISL       10                 19
# 68173  2021-06-29 11:00:00      70     ISL       17                  4
# 62828  2021-06-29 11:00:00      70     EST       17                 14
# 42396  2021-06-29 11:00:00      70     NCL       10                308
# 6827   2021-06-29 11:00:00      70     KEN       17                 15
# 61466  2021-06-29 11:00:00      70     NCL       17                 14
# ...

# %%
# Out:
# <Axes: >

# %% [markdown]
# ### Ad metrics

# %%
ads_total = df.groupby('ad_type').agg({
    'total_impressions': ['mean', 'count'],
    'total_value': 'mean',
    'eCPM': ['mean', 'median']
})

ads_total
# Out:
#         total_impressions        total_value      eCPM
#                      mean  count        mean      mean median
# ad_type
# 2             4393.093305  15101    5.464501  6.463151    5.0
# 10            4936.828824  39398    4.280325  7.063945    5.0
# 15            4189.255816  14014    5.058630  6.186891    2.0
# 17            2517.341412  27685    2.273657  5.292258    5.0

# %%
# Out:
# <Axes: >
